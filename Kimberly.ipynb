# %% [markdown]
# # Global Malnutrition Analysis

# %% [markdown]
# In this project, we have analyzed several sources of data relevant to malnutrition amongst children ranging from the ages of infant to 5 years old. The major components of our analysis is as follows:
#
# 1. Extracting data from various sources including UNICEF, World Bank and more (listed below)
# 2. Combining malnutrition data into a single dataframe with information regarding wasting, overweight and stunting conditions amongst the global population of children from 1978 to 2021
# 3. Analysing countries with the highest prevalence of malnutrition
# 4. Developing a world heat map visualization to see the global malnutrition trend over the years
# 5. Assessing a relationship, if any, between COVID deaths experienced by the country and prevalence of malnutrition among children

# %% [markdown]
# ## Data Sources

# %% [markdown]
# 1. The malnutrtion data is from UNICEF.org and it has the ratio of kids under 5 with stunt/severe stunting, wasted/severe wasted, and overweight problems at country-level from 1970 to 2021.(datalink: https://data.unicef.org/resources/data_explorer/unicef_f/?ag=UNICEF&df=GLOBAL_DATAFLOW&ver=1.0&dq=.NT_ANT_HAZ_NE2+NT_ANT_HAZ_NE3..&startPeriod=2016&endPeriod=2021).
#
# 2. COVID deaths data from OurWorldInData.org. (datalink: https://ourworldindata.org/coronavirus-source-data)
#
# 3. Continent & Country Data from Kaggle. (datalink: https://www.kaggle.com/statchaitya/country-to-continent)

# %% [markdown]
# ## 1. Data Gathering

# %%
# download necessary packages

import numpy as np  #calculation
from numpy import linalg as LA
import pandas as pd  #dataframe
import scipy as sp #calculation
from scipy.interpolate import interp1d #smooth plot
import seaborn as sns #graph
import matplotlib.pyplot as plt #plot
from sklearn import linear_model #linear regression
import statsmodels.api as sm #linear regression model
from seaborn import heatmap #map
import os
import geopandas as gpd
import descartes
from sklearn.preprocessing import MinMaxScaler, normalize
import warnings
warnings.filterwarnings('ignore')

# %%
# download datasets and show headlines
wasted_data = pd.read_csv(os.getcwd()+"/data files/Wasted_Data.csv")
display(wasted_data[:3])
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  NT_ANT_WHZ_NE2: Weight-for-height <-2 SD (wast...  F: Female
# 1  NT_ANT_WHZ_NE2: Weight-for-height <-2 SD (wast...  F: Female
# 2  NT_ANT_WHZ_NE2: Weight-for-height <-2 SD (wast...  F: Female
#
#   TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                    2004                          9.3
# 1                    2013                          8.7
# 2                    2018                          4.1
#
#   UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                        0: Units                      PCNT: %
# 1                        0: Units                      PCNT: %
# 2                        0: Units                      PCNT: %
#
#   OBS_STATUS:Observation Status OBS_CONF:Observation confidentaility  ...  \
# 0       ER: External Reanalysis                              F: Free  ...
# 1                RA: Reanalysed                              F: Free  ...
# 2                RA: Reanalysed                              F: Free  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0                                 436.0
# 1                             2080089.9
# 2                                9593.1
#
#                    OBS_FOOTNOTE:Observation footnote  \
# 0  Reduced age range Age 0-5 months not covered  ...
# 1  Oedema data was not considered in the analysis...
# 2  Oedema data was not considered in the analysis...
#
#                      SERIES_FOOTNOTE:Series footnote  \
# 0  UNICEF/WHO/World Bank Joint Malnutrition Estim...
# 1  UNICEF/WHO/World Bank Joint Malnutrition Estim...
# 2  UNICEF/WHO/World Bank Joint Malnutrition Estim...
#
#                              DATA_SOURCE:Data Source  \
# 0  Summary report of the national nutrition surve...
# 1         Afghanistan National Nutrition Survey 2013
# 2                     Afghanistan Health Survey 2018
#
#   SOURCE_LINK:Citation of or link to the data source  \
# 0  https://data.unicef.org/topic/nutrition/malnut...
# 1  https://data.unicef.org/topic/nutrition/malnut...
# 2  https://data.unicef.org/topic/nutrition/malnut...
#
#                                  CUSTODIAN:Custodian  \
# 0  UNICEF Division of Data  Analysis  Planning an...
# 1  UNICEF Division of Data  Analysis  Planning an...
# 2  UNICEF Division of Data  Analysis  Planning an...
#
#   TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                           MOF: Middle of fieldwork
# 1                           MOF: Middle of fieldwork
# 2                           MOF: Middle of fieldwork
#
#   REF_PERIOD:Reference Period  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
#   COVERAGE_TIME:The period of time for which data are provided  \
# 0                                          1997-2018
# 1                                          1997-2018
# 2                                          1997-2018
#
#            AGE:Current age
# 0  Y0T4: Under 5 years old
# 1  Y0T4: Under 5 years old
# 2  Y0T4: Under 5 years old
#
# [3 rows x 22 columns]

# %%
# make sure the data downloaded is for wasting only
wasted_data['INDICATOR:Indicator'].unique()
# Out:
# array(['NT_ANT_WHZ_NE2: Weight-for-height <-2 SD (wasting)'], dtype=object)

# %%
ser_wasted_data=pd.read_csv(os.getcwd()+"/data files/Severe_Wasted_Data.csv")
display(ser_wasted_data[:1])
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  NT_ANT_WHZ_NE3: Weight-for-height <-3 SD (seve...  F: Female
#
#   TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                    2004                          4.3
#
#   UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                        0: Units                      PCNT: %
#
#   OBS_STATUS:Observation Status OBS_CONF:Observation confidentaility  ...  \
# 0       ER: External Reanalysis                              F: Free  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0                                 436.0
#
#                    OBS_FOOTNOTE:Observation footnote  \
# 0  Reduced age range Age 0-5 months not covered  ...
#
#                      SERIES_FOOTNOTE:Series footnote  \
# 0  UNICEF/WHO/World Bank Joint Malnutrition Estim...
#
#                              DATA_SOURCE:Data Source  \
# 0  Summary report of the national nutrition surve...
#
#   SOURCE_LINK:Citation of or link to the data source  \
# 0  https://data.unicef.org/topic/nutrition/malnut...
#
#                                  CUSTODIAN:Custodian  \
# 0  UNICEF Division of Data  Analysis  Planning an...
#
#   TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                           MOF: Middle of fieldwork
#
#   REF_PERIOD:Reference Period  \
# 0                         NaN
#
#   COVERAGE_TIME:The period of time for which data are provided  \
# 0                                          2004-2018
#
#            AGE:Current age
# 0  Y0T4: Under 5 years old
#
# [1 rows x 22 columns]

# %%
ser_wasted_data['INDICATOR:Indicator'].unique() #for severe wasting only
# Out:
# array(['NT_ANT_WHZ_NE3: Weight-for-height <-3 SD (severe wasting)'],
#       dtype=object)

# %%
stunted_data = pd.read_csv(os.getcwd()+"/data files/Stunt_Data.csv")
display(stunted_data[:1])
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                 INDICATOR:Indicator    SEX:Sex  \
# 0  NT_ANT_HAZ_NE2: Height-for-age <-2 SD (stunting)  F: Female
#
#   TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                    2004                         58.5
#
#   UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                        0: Units                      PCNT: %
#
#   OBS_STATUS:Observation Status OBS_CONF:Observation confidentaility  ...  \
# 0       ER: External Reanalysis                              F: Free  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0                                 436.0
#
#                    OBS_FOOTNOTE:Observation footnote  \
# 0  Reduced age range Age 0-5 months not covered  ...
#
#                      SERIES_FOOTNOTE:Series footnote  \
# 0  UNICEF/WHO/World Bank Joint Malnutrition Estim...
#
#                              DATA_SOURCE:Data Source  \
# 0  Summary report of the national nutrition surve...
#
#   SOURCE_LINK:Citation of or link to the data source  \
# 0  https://data.unicef.org/topic/nutrition/malnut...
#
#                                  CUSTODIAN:Custodian  \
# 0  UNICEF Division of Data  Analysis  Planning an...
#
#   TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                           MOF: Middle of fieldwork
#
#   REF_PERIOD:Reference Period  \
# 0                         NaN
#
#   COVERAGE_TIME:The period of time for which data are provided  \
# 0                                          1997-2018
#
#            AGE:Current age
# 0  Y0T4: Under 5 years old
#
# [1 rows x 22 columns]

# %%
stunted_data['INDICATOR:Indicator'].unique() #stunting only
# Out:
# array(['NT_ANT_HAZ_NE2: Height-for-age <-2 SD (stunting)'], dtype=object)

# %%
ser_stunted_data = pd.read_csv("Severe_Stunt_Data.csv")
display(ser_stunted_data[:1])
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  NT_ANT_HAZ_NE3: Height-for-age <-3 SD (Severe ...  F: Female
#
#   TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                    2004                         30.9
#
#   UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                        0: Units                      PCNT: %
#
#   OBS_STATUS:Observation Status OBS_CONF:Observation confidentaility  ...  \
# 0       ER: External Reanalysis                              F: Free  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0                                 436.0
#
#                    OBS_FOOTNOTE:Observation footnote  \
# 0  Reduced age range Age 0-5 months not covered  ...
#
#                      SERIES_FOOTNOTE:Series footnote  \
# 0  UNICEF/WHO/World Bank Joint Malnutrition Estim...
#
#                              DATA_SOURCE:Data Source  \
# 0  Summary report of the national nutrition surve...
#
#   SOURCE_LINK:Citation of or link to the data source  \
# 0  https://data.unicef.org/topic/nutrition/malnut...
#
#                                  CUSTODIAN:Custodian  \
# 0  UNICEF Division of Data  Analysis  Planning an...
#
#   TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                           MOF: Middle of fieldwork
#
#   REF_PERIOD:Reference Period  \
# 0                         NaN
#
#   COVERAGE_TIME:The period of time for which data are provided  \
# 0                                          2004-2018
#
#            AGE:Current age
# 0  Y0T4: Under 5 years old
#
# [1 rows x 22 columns]

# %%
ser_stunted_data['INDICATOR:Indicator'].unique() #severe stunting only
# Out:
# array(['NT_ANT_HAZ_NE3: Height-for-age <-3 SD (Severe Stunting)'],
#       dtype=object)

# %%
overweight_data = pd.read_csv(os.getcwd()+"/data files/Overweight_Data.csv")
display(overweight_data[:1])
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  NT_ANT_WHZ_PO2: Weight-for-height >+2 SD (over...  F: Female
#
#   TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                    2004                          2.6
#
#   UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                        0: Units                      PCNT: %
#
#   OBS_STATUS:Observation Status OBS_CONF:Observation confidentaility  ...  \
# 0       ER: External Reanalysis                              F: Free  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0                                 436.0
#
#                    OBS_FOOTNOTE:Observation footnote  \
# 0  Reduced age range Age 0-5 months not covered  ...
#
#                      SERIES_FOOTNOTE:Series footnote  \
# 0  UNICEF/WHO/World Bank Joint Malnutrition Estim...
#
#                              DATA_SOURCE:Data Source  \
# 0  Summary report of the national nutrition surve...
#
#   SOURCE_LINK:Citation of or link to the data source  \
# 0  https://data.unicef.org/topic/nutrition/malnut...
#
#                                  CUSTODIAN:Custodian  \
# 0  UNICEF Division of Data  Analysis  Planning an...
#
#   TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                           MOF: Middle of fieldwork
#
#   REF_PERIOD:Reference Period  \
# 0                         NaN
#
#   COVERAGE_TIME:The period of time for which data are provided  \
# 0                                          1997-2018
#
#            AGE:Current age
# 0  Y0T4: Under 5 years old
#
# [1 rows x 22 columns]

# %%
overweight_data['INDICATOR:Indicator'].unique() #overweight only
# Out:
# array(['NT_ANT_WHZ_PO2: Weight-for-height >+2 SD (overweight)'],
#       dtype=object)

# %% [markdown]
# ## 2. Data Cleaning

# %%
# data cleaning
# rename columns

# wasted
wasted_data = wasted_data.rename(columns = {"REF_AREA:Geographic area" : "Country", "SEX:Sex" : "Sex",\
                                         "TIME_PERIOD:Time period" : "Year", "OBS_VALUE:Observation Value" : "Waste_percent",\
                                           'AGE:Current age':'Age'})
# severe_wasted
ser_wasted_data=ser_wasted_data.rename(columns = {"REF_AREA:Geographic area" : "Country", "SEX:Sex" : "Sex",\
                                           "TIME_PERIOD:Time period" : "Year", "OBS_VALUE:Observation Value" : "Severe_Waste_percent",\
                                           'AGE:Current age':'Age'})
# stunted
stunted_data = stunted_data.rename(columns = {"REF_AREA:Geographic area" : "Country", "SEX:Sex" : "Sex",\
                                          "TIME_PERIOD:Time period" : "Year", "OBS_VALUE:Observation Value" : "Stunt_percent",\
                                            'AGE:Current age':'Age'})
# severe stunted
ser_stunted_data = ser_stunted_data.rename(columns = {"REF_AREA:Geographic area" : "Country", "SEX:Sex" : "Sex",\
                                          "TIME_PERIOD:Time period" : "Year", "OBS_VALUE:Observation Value" : "Severe_Stunt_percent",\
                                           'AGE:Current age':'Age'})
# overweight
overweight_data = overweight_data.rename(columns = {"REF_AREA:Geographic area" : "Country", "SEX:Sex" : "Sex",\
                                           "TIME_PERIOD:Time period" : "Year", "OBS_VALUE:Observation Value" : "Overweight_percent",\
                                            "INDICATOR:Indicator":"Overweight_Indicator",'AGE:Current age':'Age'})

# %%
# Only keep the relevant data columns

wasted_df=wasted_data[['Country','Sex','Year','Waste_percent','Age']]
ser_wasted_df=ser_wasted_data[['Country','Sex','Year','Severe_Waste_percent','Age']]
stunted_df=stunted_data[['Country','Sex','Year','Stunt_percent','Age']]
ser_stunted_df=ser_stunted_data[['Country','Sex','Year','Severe_Stunt_percent','Age']]
overweight_df=overweight_data[['Country','Sex','Year','Overweight_percent','Age']]

# %%
# combine with outer-join
combined_df=wasted_df.merge(ser_wasted_df,how='outer',on=['Country','Sex','Year','Age'])\
            .merge(stunted_df,how='outer',on=['Country','Sex','Year','Age'])\
            .merge(ser_stunted_df,how='outer',on=['Country','Sex','Year','Age'])\
            .merge(overweight_df,how='outer',on=['Country','Sex','Year','Age'])\
# shown sample lines
combined_df.head(3)
# Out:
#             Country        Sex  Year  Waste_percent                      Age  \
# 0  AFG: Afghanistan  F: Female  2004            9.3  Y0T4: Under 5 years old
# 1  AFG: Afghanistan  F: Female  2013            8.7  Y0T4: Under 5 years old
# 2  AFG: Afghanistan  F: Female  2018            4.1  Y0T4: Under 5 years old
#
#    Severe_Waste_percent  Stunt_percent  Severe_Stunt_percent  \
# 0                   4.3           58.5                  30.9
# 1                   3.5           39.5                  19.9
# 2                   1.4           38.1                  20.0
#
#    Overweight_percent
# 0                 2.6
# 1                 5.8
# 2                 4.2

# %%
# Calculate total waste percent column from adding percentage with normal waste condition and percentage with severe waste condition
combined_df['Waste_total_percent']=combined_df['Waste_percent']+combined_df['Severe_Waste_percent']
combined_df['Stunt_total_percent']=combined_df['Stunt_percent']+combined_df['Severe_Stunt_percent']
combined_df.head(1)
# Out:
#             Country        Sex  Year  Waste_percent                      Age  \
# 0  AFG: Afghanistan  F: Female  2004            9.3  Y0T4: Under 5 years old
#
#    Severe_Waste_percent  Stunt_percent  Severe_Stunt_percent  \
# 0                   4.3           58.5                  30.9
#
#    Overweight_percent  Waste_total_percent  Stunt_total_percent
# 0                 2.6                 13.6                 89.4

# %%
# pop the previous waste & stunt columns, only keep the sum column
cols=['Waste_percent','Severe_Waste_percent','Stunt_percent','Severe_Stunt_percent']
for c in cols:
    combined_df.pop(c)
combined_df.head(1)
# Out:
#             Country        Sex  Year                      Age  \
# 0  AFG: Afghanistan  F: Female  2004  Y0T4: Under 5 years old
#
#    Overweight_percent  Waste_total_percent  Stunt_total_percent
# 0                 2.6                 13.6                 89.4

# %%
# save the column names for future uses
mal_type=['Mean','Overweight_percent','Waste_total_percent','Stunt_total_percent']
#malnutrition type 0=mean
#malnutrition type 1=overweight
#malnutrition type 2=waste
#malnutrition type 3=stunt

# %%
# Observe properties of some columns
# 1. Is age all under 5?
combined_df['Age'].unique()
print('All data are for kids under 5 years old.')
# Out:
# All data are for kids under 5 years old.

# %%
# Since the data only for kids under 5, we can delete this column 
del combined_df['Age']

# %%
# 2. Format sex column
combined_df['Sex'].unique()
# Out:
# array(['F: Female', 'M: Male', '_T: Total'], dtype=object)

# %%
# only leave the "Total" for analysis
combined_df["Sex"] = combined_df["Sex"].str[1]
combined_df=combined_df[combined_df["Sex"]=='T']

# %%
# 3. Format countries and regions
country_count=len(combined_df['Country'].unique())
print('There are a total number of '+ str(country_count) + ' countries/regions in the DataFrame initially.')
# Out:
# There are a total number of 239 countries/regions in the DataFrame initially.

# %%
# Format countries, separate to 3 digit ISO code and name
split_countries= combined_df["Country"].str.split(':', expand=True)

# join to combine df
combined_df = split_countries.join(combined_df)

# rename columns
combined_df = combined_df.rename(columns = {0 : "ISO Code", 1 : "Country Name"})

# format the region
combined_df["Country Name"] = combined_df["Country Name"].str.strip()

# filter only the countrys not regions
combined_df = combined_df[combined_df["ISO Code"].str.contains("_")==False]

# remove previous columns
del combined_df['Country']

combined_df.head(3)
# Out:
#   ISO Code Country Name Sex  Year  Overweight_percent  Waste_total_percent  \
# 6      AFG  Afghanistan   T  1997                 6.5                  NaN
# 7      AFG  Afghanistan   T  2004                 4.6                 12.1
# 8      AFG  Afghanistan   T  2013                 5.3                 13.5
#
#    Stunt_total_percent
# 6                  NaN
# 7                 91.1
# 8                 60.8

# %%
new_country_count=len(combined_df['Country Name'].unique())
print('There are now a total number of '+ str(new_country_count) + ' countries in the DataFrame now.')
# Out:
# There are now a total number of 157 countries in the DataFrame now.

# %%
# 4. Observe the Year range
combined_df['Year'].unique()
# Out:
# array(['1997', '2004', '2013', '2018', '2000', '2005', '2009', '2017',
#        '1987', '1992', '1995', '2002', '2006', '2012', '2019', '1996',
#        '2007', '2015', '1994', '1998', '2010', '2016', '2001', '2011',
#        '1989', '1986', '1990', '1991', '1993', '1999', '2003',
#        '2013-02-16', '2013-06-16', '2014', '2008', '1985', '2019-03-14',
#        '2019-11-07', '2019-08-12', '2019-08-27', '1988', '1998-01-01',
#        '1998-12-01', '2018-03-13', '2018-04-09', '2020', '2012-01-06',
#        '2012-08-06', '2019-01-15', '2019-09-15', '1994-01-15',
#        '1994-12-17', '2016-01-15', '2016-05-11', '2016-12-01',
#        '2015-05-22', '2015-09-05', '2018-07-24', '2018-09-27',
#        '2010-08-22', '2010-10-24', '2016-05-15', '2016-10-01',
#        '2006-03-28', '2006-11-01', '2010-06-05', '2010-10-29',
#        '2012-04-11', '2012-07-16', '2018-04-02', '2018-10-23', '1983',
#        '2015-01-09', '2015-04-26', '2019-02-09', '2019-08-16',
#        '2017-07-01', '2017-09-19', '2010-10-04', '2010-12-21'],
#       dtype=object)

# %%
# format the year columns
# year remove some date, only keep year
combined_df["Year"] =  pd.to_datetime(combined_df["Year"]).dt.year
# observe new column values
years=combined_df['Year'].unique()
print(sorted(years))
# Out:
# [1983, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
# we want to group by years and replace the three percentages with the country's overall reports in a year
clean_df=combined_df.groupby(['ISO Code','Country Name','Year'],as_index=False).mean()

# %%
combined_df=clean_df.merge(clean_df,how='left',on=['ISO Code','Country Name','Year'])
cols=combined_df.columns.tolist()
combined_df=combined_df[cols[:-3]]
combined_df.rename(columns={cols[3]:mal_type[1],cols[4]:mal_type[2],cols[5]:mal_type[3]},inplace=True)
combined_df.head(3)
# Out:
#   ISO Code Country Name  Year  Overweight_percent  Waste_total_percent  \
# 0      AFG  Afghanistan  1997                 6.5                  NaN
# 1      AFG  Afghanistan  2004                 4.6                 12.1
# 2      AFG  Afghanistan  2013                 5.3                 13.5
#
#    Stunt_total_percent
# 0                  NaN
# 1                 91.1
# 2                 60.8

# %%
# 5. Drop rows with Na values
combined_df.dropna(inplace=True) #drop NaN

display(combined_df[:3])
# Out:
#   ISO Code Country Name  Year  Overweight_percent  Waste_total_percent  \
# 1      AFG  Afghanistan  2004                 4.6                 12.1
# 2      AFG  Afghanistan  2013                 5.3                 13.5
# 3      AFG  Afghanistan  2018                 4.1                  6.7
#
#    Stunt_total_percent
# 1                 91.1
# 2                 60.8
# 3                 57.6

# %%
# create a new column of malnutrition score for mean of the five malnutrition factor
combined_df['Mean']=combined_df.iloc[:,4:9].mean(axis=1)
combined_df.head(3)
# Out:
#   ISO Code Country Name  Year  Overweight_percent  Waste_total_percent  \
# 1      AFG  Afghanistan  2004                 4.6                 12.1
# 2      AFG  Afghanistan  2013                 5.3                 13.5
# 3      AFG  Afghanistan  2018                 4.1                  6.7
#
#    Stunt_total_percent   Mean
# 1                 91.1  51.60
# 2                 60.8  37.15
# 3                 57.6  32.15

# %% [markdown]
# ## 3. Creating Visualizations

# %%
# now observe overweight/waste/stunt 
fig, axis = plt.subplots(2,2) 
fig.suptitle("World's Children Malnutrition Histogram")

# Mean
axis[0,0].hist(combined_df[mal_type[0]],bins=30,color='deepskyblue')
axis[0,0].set_title("Mean")
# Overweight
axis[0,1].hist(combined_df[mal_type[1]],bins=30,color='royalblue')
axis[0,1].set_title("Overweight")
# Waste
axis[1,0].hist(combined_df[mal_type[2]],bins=30,color='orange')
axis[1,0].set_title("Waste")
# Stunt
axis[1,1].hist(combined_df[mal_type[3]],bins=30,color='forestgreen')
axis[1,1].set_title("Stunt")

fig.set_size_inches(15, 10)
plt.show()

# %%
# now observe overweight/waste/stunt 
fig, axis2 = plt.subplots(2,2) 
fig.suptitle("World's Children Malnutrition Boxplot")

# Mean
axis2[0,0].boxplot(combined_df[mal_type[0]])
axis2[0,0].set_title("Mean")

# Overweight
axis2[0,1].boxplot(combined_df[mal_type[1]])
axis2[0,1].set_title("Overweight")

# Waste
axis2[1,0].boxplot(combined_df[mal_type[2]])
axis2[1,0].set_title("Waste")

# Stunt
axis2[1,1].boxplot(combined_df[mal_type[3]])
axis2[1,1].set_title("Stunt")

fig.set_size_inches(15, 10)
plt.show()

# %%
# observe correlation map
corr = combined_df.corr() # train is a pandas dataframe 
plt.figure(figsize = (8, 8))
heatmap(corr, cmap = 'Blues',annot=True)
plt.title('Correlation heatmap for all malnutrition types')
plt.show()

# %%
# Now Observe US first
country_df=combined_df.copy()
country_df.index = country_df["ISO Code"] #make the iso code as index 

country_df.loc['USA'].plot(x='Year', y=['Overweight_percent','Waste_total_percent','Stunt_total_percent'])
plt.title('US Children Malnutrition')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig.set_size_inches(10, 10)
plt.show()

# %%
# create a function to smooth the graph later
# use interpld from scipy to smooth the lines

def countryGraph(countryISO):
    countryData=country_df.loc[countryISO]
    country_name=countryData['Country Name'][1]
    x=countryData['Year'] # x is the year
    X_=np.linspace(x.min(), x.max(),300) #X_ is the new x with linspace
    d=countryData[mal_type[1:]] #z is actual datapoints
    for i in range(1,4): 
        y=countryData[mal_type[i]] #interate the plot each y as malnutrtion types
        smooth_model = interp1d(x, y, kind = "cubic") #smooth with interplation
        f=smooth_model(X_) #f is the new y 
        plt.plot(X_,f) #plot
    plt.plot(x, d, 'ro')
    plt.title(country_name+str(' Children Malnutrition Chart'))
    plt.legend(mal_type[1:])
    plt.show()
countryGraph('USA')

# %%
# TRYING COMBINE GRAPHS
#df=country_df.loc['USA']
#x=country_df.loc['USA']['Year']
#y=country_df.loc['USA'][['Overweight_percent','Waste_total_percent','Stunt_total_percent']]

#plt.plot(x, y, 'o')
#countryGraph('USA')

#plt.title('US Children Interpolation Malnutrition')
#plt.legend(loc='center right', bbox_to_anchor=(1, 0.5))
#fig.set_size_inches(10, 10)
#countryGraph('USA')
#plt.show()

# %%
# US has lower stunt and waste ratio but higher overweight problem for children under 5

# %%
# groupby countries, find the country with highest mean malnutrition value
# because the minimum of cubic spline required datapoint is 4, we want to filter the country with 4 or more years of report
country_count=combined_df.groupby(by=['ISO Code','Country Name'],as_index=False).count()
country_count.rename(columns={'Mean':'Count'},inplace=True)
country_count=country_count[country_count['Count']>=4]
country_count=country_count[['ISO Code','Count']]
display(country_count[:3])
# Out:
#   ISO Code  Count
# 2      ALB      4
# 4      ARM      5
# 5      AZE      4

# %%
#country_rank.sort_values(by='Mean',ascending=True,inplace=True)
country_rank=combined_df.groupby(by=['ISO Code','Country Name'],as_index=False).mean()
country_rank=country_rank.merge(country_count,how='inner',on='ISO Code')
country_rank=country_rank.sort_values(by='Mean')
country_rank["Year"]=country_rank["Year"].astype(int)
display(country_rank)
# Out:
#    ISO Code     Country Name  Year  Overweight_percent  Waste_total_percent  \
# 80      USA    United States  2007            8.109091             0.481818
# 36      KWT           Kuwait  2007            8.328571             3.178571
# 45      MKD  North Macedonia  2008           12.350000             3.175000
# 67      SRB           Serbia  2012           14.925000             4.675000
# 79      URY          Uruguay  2010           10.260000             2.080000
# ..      ...              ...   ...                 ...                  ...
# 53      NER            Niger  2010            0.910000            17.070000
# 42      MDG       Madagascar  2006            2.575000            11.025000
# 3       BDI          Burundi  2012            2.080000             6.900000
# 82      YEM            Yemen  2003            4.500000            20.200000
# 75      TLS      Timor-Leste  2007            3.650000            20.725000
#
#     Stunt_total_percent       Mean  Count
# 80             3.300000   1.890909     11
# 36             5.807143   4.492857     14
# 45             9.525000   6.350000      4
# 67             9.300000   6.987500      4
# 79            13.100000   7.590000      5
# ..                  ...        ...    ...
# 53            67.623333  42.346667     15
# 42            74.525000  42.775000      4
# 3             84.900000  45.900000      5
# 82            80.666667  50.433333      6
# 75            83.300000  52.012500      4
#
# [86 rows x 8 columns]

# %%
clean=country_rank.groupby(["Country Name", "Year"],as_index = False).mean()

iso_codes = combined_df[["ISO Code", "Country Name"]].drop_duplicates()

clean_rank = iso_codes.merge(clean, on = "Country Name")

display(clean_rank)
# Out:
#    ISO Code  Country Name  Year  Overweight_percent  Waste_total_percent  \
# 0       ALB       Albania  2007           23.625000            11.750000
# 1       ARM       Armenia  2005           13.620000             5.540000
# 2       AZE    Azerbaijan  2007           11.150000             8.975000
# 3       BDI       Burundi  2012            2.080000             6.900000
# 4       BEN         Benin  2010            2.050000             7.425000
# ..      ...           ...   ...                 ...                  ...
# 81      VNM      Viet Nam  2006            3.487500            10.568750
# 82      YEM         Yemen  2003            4.500000            20.200000
# 83      ZAF  South Africa  2014           12.925000             5.050000
# 84      ZMB        Zambia  2003            7.228571             7.585714
# 85      ZWE      Zimbabwe  2007            5.712500             5.375000
#
#     Stunt_total_percent       Mean  Count
# 0             38.550000  25.150000    4.0
# 1             22.080000  13.810000    5.0
# 2             30.975000  19.975000    4.0
# 3             84.900000  45.900000    5.0
# 4             47.700000  27.562500    4.0
# ..                  ...        ...    ...
# 81            45.643750  28.106250   16.0
# 82            80.666667  50.433333    6.0
# 83            31.775000  18.412500    4.0
# 84            68.957143  38.271429    7.0
# 85            41.225000  23.300000    8.0
#
# [86 rows x 8 columns]

# %%
# keep a record of the top 5 and bot 5 country with S&W mean for observation
top5=clean_rank[:5]['Country Name'].tolist()
display(top5)
# the five country with least percentages of Stunt & Waste mean
# Out:
# ['Albania', 'Armenia', 'Azerbaijan', 'Burundi', 'Benin']

# %%
top5ISO=clean_rank[:5]['ISO Code'].tolist()
display(top5ISO)
# 5 countries' corresponding iso code
# Out:
# ['ALB', 'ARM', 'AZE', 'BDI', 'BEN']

# %%
# Plot graphs to observe the trend for each malnutrition problem at country level for top 5 countries
for i in top5ISO:
    countryGraph(i)

# %%
# i think we dont need this anymore
# Plot graphs to observe the trend for each malnutrition problem at country level for top 5 countries

#for c in zip(top5,top5ISO):
#    country_df.loc[c[1]].plot(x='Year', y=mal_type[1:])
#    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#    plt.title(c[0])
#plt.show()

# %%
bot5=clean_rank[-5:]['Country Name'].tolist()
display(bot5) # the five country with high percentages of Stunt & Waste mean
# Out:
# ['Viet Nam', 'Yemen', 'South Africa', 'Zambia', 'Zimbabwe']

# %%
bot5ISO=clean_rank[-5:]['ISO Code'].tolist()
display(bot5ISO)
# Out:
# ['VNM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

# %%
#graph bottom 5 countries malnutrition graphs
for i in bot5ISO:
    countryGraph(i)

# %% [markdown]
# ### Continent Analysis

# %%
continent = pd.read_csv(os.getcwd()+"/data files/countryContinent.csv")

continent = continent[["country", "continent"]]

joined = clean_rank.merge(continent, left_on = "Country Name", right_on = "country")

joined = joined.drop(columns = "country")

# %%
display(joined[:3])
# Out:
#   ISO Code Country Name  Year  Overweight_percent  Waste_total_percent  \
# 0      ALB      Albania  2007              23.625               11.750
# 1      ARM      Armenia  2005              13.620                5.540
# 2      AZE   Azerbaijan  2007              11.150                8.975
#
#    Stunt_total_percent    Mean  Count continent
# 0               38.550  25.150    4.0    Europe
# 1               22.080  13.810    5.0      Asia
# 2               30.975  19.975    4.0      Asia

# %%
by_continent = joined.groupby(["Year", "continent"], as_index = False).mean()

display(by_continent[:3])
# Out:
#    Year continent  Overweight_percent  Waste_total_percent  \
# 0  1999      Asia              7.0875             4.262500
# 1  2000  Americas              4.7500             2.133333
# 2  2000    Europe              9.1000             4.725000
#
#    Stunt_total_percent    Mean  Count
# 0            31.537500  17.900    8.0
# 1            34.316667  18.225    6.0
# 2            18.775000  11.750    4.0

# %%
by_continent["Smooth Mean"] = by_continent['Mean'].rolling(2).sum()

by_continent["Waste Smooth"] = by_continent['Waste_total_percent'].rolling(5).sum()

by_continent["Stunt Smooth"] = by_continent['Stunt_total_percent'].rolling(5).sum()

by_continent["Overweight Smooth"] = by_continent['Overweight_percent'].rolling(5).sum()

display(by_continent[:3])
# Out:
#    Year continent  Overweight_percent  Waste_total_percent  \
# 0  1999      Asia              7.0875             4.262500
# 1  2000  Americas              4.7500             2.133333
# 2  2000    Europe              9.1000             4.725000
#
#    Stunt_total_percent    Mean  Count  Smooth Mean  Waste Smooth  \
# 0            31.537500  17.900    8.0          NaN           NaN
# 1            34.316667  18.225    6.0       36.125           NaN
# 2            18.775000  11.750    4.0       29.975           NaN
#
#    Stunt Smooth  Overweight Smooth
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN

# %%
sns.lineplot(x="Year", y="Smooth Mean",
             hue="continent",data=by_continent, palette="husl", lw = 3).set(title = "Average % of Children with Malnutrition")

sns.set(rc={'figure.figsize':(15,6)})

sns.set_style("white")

# %%
sns.lineplot(x="Year", y="Waste Smooth",
             hue="continent",data=by_continent, palette="husl", lw = 3).set(title = "% of Under 5 Year-Old with Wasting")

sns.set(rc={'figure.figsize':(15,6)})

sns.set_style("white")

# %%
sns.lineplot(x="Year", y="Stunt Smooth",
             hue="continent",data=by_continent, palette="husl", lw = 3).set(title = "% of Under 5 Year-Old with Stunting")

sns.set(rc={'figure.figsize':(15,6)})

sns.set_style("white")

# %%
sns.lineplot(x="Year", y="Overweight Smooth",
             hue="continent",data=by_continent, palette="husl", lw = 3).set(title = "% of Overweight Children Under 5 Years-Old")

sns.set(rc={'figure.figsize':(15,6)})

sns.set_style("white")

# %%
# ## SHEENA TRYING SMOOTH THIS
# continents=by_continent['continent'].unique()
# display(by_continent[by_continent['continent']=='Europe'])
# #display(continents)


# for c in sorted(continents):
#     dfc=by_continent[by_continent['continent']==c]
#     xc=dfc['Year']
#     Xc=np.linspace(xc.min(), xc.max(),300)
#     yc=dfc['Mean']
#     f1= interp1d(xc, yc, kind = "cubic")
#     yc_=f1(Xc)

# #Plotting the Graph
#     plt.plot(Xc, yc_)

# # not working becuase x was repeated?? 
# # https://stackoverflow.com/questions/68100959/plot-smooth-curve-with-duplicate-values-in-list

# %% [markdown]
# ## Mapping

# %% [markdown]
# Let's view how these effects of malnutrition apply on a global scale. In this section, you'll see maps of the severity of each measurment of malnutrition as recorded in year 2020.

# %%
# import map
world_map = gpd.read_file(os.getcwd()+'/World_Map/World_Countries__Generalized_.shp')

# %%
map_all = world_map.merge(combined_df, how='left', left_on='COUNTRYAFF', right_on='Country Name')
print('Verifying data has combined')
display(map_all.head(2))
# Out:
# Verifying data has combined
#    FID         COUNTRY ISO     COUNTRYAFF AFF_ISO  SHAPE_Leng  SHAPE_Area  \
# 0    1  American Samoa  AS  United States      US    0.600124     0.01372
# 1    1  American Samoa  AS  United States      US    0.600124     0.01372
#
#                                             geometry ISO Code   Country Name  \
# 0  POLYGON ((-170.74390 -14.37555, -170.74942 -14...      USA  United States
# 1  POLYGON ((-170.74390 -14.37555, -170.74942 -14...      USA  United States
#
#      Year  Overweight_percent  Waste_total_percent  Stunt_total_percent  Mean
# 0  1991.0                 6.1                  0.6                  3.6   2.1
# 1  2000.0                 8.3                  0.6                  3.8   2.2

# %%
print('Overweight observations range', np.nanmin(map_all['Overweight_percent'].values), '% to', np.nanmax(map_all['Overweight_percent'].values), '%.')
print('Wasted observations range', np.nanmin(map_all['Waste_total_percent'].values), '% to', np.nanmax(map_all['Waste_total_percent'].values), '%.')
print('Stunted observations range', np.nanmin(map_all['Stunt_total_percent'].values), '% to', np.nanmax(map_all['Stunt_total_percent'].values), '%.')
# Out:
# Overweight observations range 0.1 % to 30.1 %.
# Wasted observations range 0.1 % to 37.5 %.
# Stunted observations range 0.9 % to 101.9 %.

# %%
# map with all overweight indicators
vmin, vmax = 0, np.nanmax(map_all['Overweight_percent'].values)
coloro = 'PuBu'

figo, axo = plt.subplots(1, figsize = (15,12))
map_all.plot(column='Overweight_percent', cmap=coloro, ax=axo, linewidth=0.2, edgecolors='0.3')
bar_infoo = plt.cm.ScalarMappable(cmap=coloro, norm=plt.Normalize(vmin=vmin, vmax=vmax))
axo.set_title('Percent of overweight children under age 5 around the world in 2020', fontdict={'fontsize':20})
axo.set_axis_off()
bar_infoo._A = []
cbar = figo.colorbar(bar_infoo, orientation='horizontal')

# %%
# map with all waste indicators
vmin, vmax = 0, np.nanmax(map_all['Waste_total_percent'].values)
colorw = 'YlOrRd'

figw, axw = plt.subplots(1, figsize = (15,12))
map_all.plot(column='Waste_total_percent', cmap=colorw, ax=axw, linewidth=0.2, edgecolors='0.3')
bar_infow = plt.cm.ScalarMappable(cmap=colorw, norm=plt.Normalize(vmin=vmin, vmax=vmax))
axw.set_title('Percent of wasted children under age 5 around the world in 2020', fontdict={'fontsize':20})
axw.set_axis_off()
bar_infow._A = []
cbar = figw.colorbar(bar_infow, orientation='horizontal')

# %%
# map with all stunt indicators
vmin, vmax = 0, np.nanmax(map_all['Stunt_total_percent'].values)
colors = 'YlGn'

figs, axs = plt.subplots(1, figsize = (15,12))
map_all.plot(column='Stunt_total_percent', cmap=colors, ax=axs, linewidth=0.2, edgecolors='0.3')
bar_infos = plt.cm.ScalarMappable(cmap=colors, norm=plt.Normalize(vmin=vmin, vmax=vmax))
axs.set_title('Percent of stunted children under age 5 around the world in 2020', fontdict={'fontsize':20})
axs.set_axis_off()
bar_infos._A = []
cbar = figs.colorbar(bar_infos, orientation='horizontal')

# %% [markdown]
# Generally, the measurements of malnutrition in children seem to be concentrated in the African continent. We see Libya and Ukraine reporting high obesity, South Sudan reporting high wasting, and many countries reporting stunting.

# %% [markdown]
# ## Animation

# %% [markdown]
# Next, we have created gifs for each malnutrition measurement that explores the changes around the world over a span of about 35 years. It is interesting to watch some areas "heal" and others report more drasticee severity.
#
# Each type of measurement has its own maximum and the scale is shown below the map. Some countries remain white, which means they have not reported the measurements to UNICEF for this time period. The map boundaries are based on recent data, so keep in mind that some country names have also changed since the beginning of the time covered. Changes in country names may affect how the data is able to be displayed because the map data is merged with the malnutrition data on each country's name.

# %%
# list of years
min_year = int(map_all['Year'].min())
max_year = int(map_all['Year'].max())+1
list_of_years = list(range(min_year, max_year))
print('Years range from', min(list_of_years), 'to', max(list_of_years))
# Out:
# Years range from 1986 to 2020

# %%
# list of countries (we will use this list again in the scoring section)
countries = map_all['COUNTRYAFF'].unique()
print('There are', len(countries), 'countries listed.')
# Out:
# There are 197 countries listed.

# %%
# save all the maps in the pictures folder
output_path = os.getcwd()+'/pictures'
filenames = []

# %% [markdown]
# The algorithm below creates a full map for each year and merges it with the data for the type of malnutrition measurement passed in. It also takes in the parameters for the color and axis to stay consistent with the established color scheme for each type of malnutrition measurement. The pictures created for each year are then saved into a file.

# %%
# algorithm to make a map for each year and save as jpg
def make_maps(map_col, color, ax, list_of_years = list(range(2000,2020))):
    # start the for loop to create one map per year
    for year in list_of_years:
        # narrow the data to the year desired
        yearly = combined_df.loc[combined_df['Year'] == year].reset_index(drop=True)
        maps = world_map.merge(yearly, how='left', left_on='COUNTRYAFF', right_on='Country Name')
        
        # normalize across all years
        vmin = min(combined_df[map_col])
        vmax = max(combined_df[map_col])

        # create map
        fig = maps.plot(column=map_col,
                        cmap=color,
                        figsize=(15,12),
                        linewidth=0.3,
                        edgecolor='0.3',
                        ax=ax,
                        norm=plt.Normalize(vmin=vmin, vmax=vmax))
        
        # add a title
        fig.set_title(map_col + ' children under age 5 in ' + str(year), \
                  fontdict={'fontsize': '20',
                             'fontweight' : '3'})

        # remove axis of chart
        fig.set_axis_off()
        
        # this will save the figure as a jpg
        filename = str(year)+'_'+map_col+'.jpg'
        filepath = os.path.join(output_path, filename)
        filenames.append(filename)
        chart = fig.get_figure()
        chart.savefig(filepath, dpi=300)

# %%
# make all the annual maps (each of these cells takes a lot of processing power and some time to run)
make_maps('Overweight_percent', coloro, axo, list_of_years)

# %%
make_maps('Waste_total_percent', colorw, axw, list_of_years)

# %%
make_maps('Stunt_total_percent', colors, axs, list_of_years)

# %% [markdown]
# This function pulls the maps for each year into a single gif. The parameters passed into this function are which folder to find the pictures, which file to save the gif, and some optional parameters on the length of the animation and how many times it loops.

# %%
# pull the created pictures into a gif
import glob
from PIL import Image

def make_gif(fp_in, fp_out, duration = 400, loop = 3):
    img, *imgs = [Image.open(f) for f in sorted(glob.glob(fp_in))]
    img.save(fp=fp_out, format='GIF', append_images=imgs,
             save_all=True, duration=duration, loop=loop)

# %%
# filepaths for overweight gif
o_fp_in = os.getcwd()+'/pictures/*_Overweight*.jpg'
o_fp_out = os.getcwd()+'/overweight.gif'

#make overweight gif
make_gif(o_fp_in, o_fp_out)

# %%
# filepaths for wasted
w_fp_in = os.getcwd()+'/pictures/*_Waste*.jpg'
w_fp_out = os.getcwd()+'/waste.gif'

#make wasted gif
make_gif(w_fp_in, w_fp_out)

# %%
# filepaths for stunted
s_fp_in = os.getcwd()+'/pictures/*_Stunt*.jpg'
s_fp_out = os.getcwd()+'/stunt.gif'

#make stunted gif
make_gif(s_fp_in, s_fp_out)

# %% [markdown]
# View the gifs we made!

# %% [markdown]
# ![SegmentLocal](overweight.gif "segment")

# %% [markdown]
# ![SegmentLocal](waste.gif "segment")

# %% [markdown]
# ![SegmentLocal](stunt.gif "segment")

# %% [markdown]
# ### Covid Analysis

# %%
# combine with COVID

# %%
###### 
# Download covid vaccine rate data to covid_data from https://ourworldindata.org/covid-vaccinations
covid_data=pd.read_csv(os.getcwd()+"/data files/owid-covid-data.csv")
covid_data.tail(5)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 151543      ZWE    Africa  Zimbabwe  2021-12-28     207548.0     2099.0
# 151544      ZWE    Africa  Zimbabwe  2021-12-29     207548.0        0.0
# 151545      ZWE    Africa  Zimbabwe  2021-12-30     211728.0     4180.0
# 151546      ZWE    Africa  Zimbabwe  2021-12-31     213258.0     1530.0
# 151547      ZWE    Africa  Zimbabwe  2022-01-01     214214.0      956.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 151543            1397.143        4940.0        32.0               17.286
# 151544            1163.429        4940.0         0.0               16.000
# 151545            1483.429        4997.0        57.0               20.286
# 151546            1503.143        5004.0         7.0               19.000
# 151547            1495.429        5017.0        13.0               18.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 151543  ...             1.6          30.7                  36.791
# 151544  ...             1.6          30.7                  36.791
# 151545  ...             1.6          30.7                  36.791
# 151546  ...             1.6          30.7                  36.791
# 151547  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 151543                         1.7            61.49                    0.571
# 151544                         1.7            61.49                    0.571
# 151545                         1.7            61.49                    0.571
# 151546                         1.7            61.49                    0.571
# 151547                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 151543                                   NaN                          NaN
# 151544                                   NaN                          NaN
# 151545                                   NaN                          NaN
# 151546                                   NaN                          NaN
# 151547                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 151543               NaN                                      NaN
# 151544               NaN                                      NaN
# 151545               NaN                                      NaN
# 151546               NaN                                      NaN
# 151547               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
#before 12/31/2020, the total number of cases for each countries
covid_data=covid_data[covid_data['date']<'2021-01-01']
covid_2020=covid_data.groupby(by='iso_code').max()
display(covid_2020[:5])
# Out:
#               continent     location        date  total_cases  new_cases  \
# iso_code
# ABW       North America        Aruba  2020-12-31       5489.0      176.0
# AFG                Asia  Afghanistan  2020-12-31      52330.0     1241.0
# AGO              Africa       Angola  2020-12-31      17553.0      355.0
# AIA       North America     Anguilla  2020-12-31         13.0        3.0
# ALB              Europe      Albania  2020-12-31      58316.0      879.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ABW                   90.143          49.0         3.0                1.000
# AFG                  758.571        2189.0        49.0               26.429
# AGO                  261.857         405.0        12.0                4.571
# AIA                    0.571           NaN         NaN                  NaN
# ALB                  799.143        1181.0        19.0               16.286
#
#           total_cases_per_million  ...  female_smokers  male_smokers  \
# iso_code                           ...
# ABW                     51205.747  ...             NaN           NaN
# AFG                      1313.655  ...             NaN           NaN
# AGO                       517.275  ...             NaN           NaN
# AIA                       859.504  ...             NaN           NaN
# ALB                     20298.413  ...             7.1          51.2
#
#           handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# iso_code
# ABW                          NaN                         NaN            76.29
# AFG                       37.746                        0.50            64.83
# AGO                       26.664                         NaN            61.15
# AIA                          NaN                         NaN            81.88
# ALB                          NaN                        2.89            78.57
#
#           human_development_index  excess_mortality_cumulative_absolute  \
# iso_code
# ABW                           NaN                                  66.2
# AFG                         0.511                                   NaN
# AGO                         0.581                                   NaN
# AIA                           NaN                                   NaN
# ALB                         0.795                                5812.4
#
#           excess_mortality_cumulative  excess_mortality  \
# iso_code
# ABW                             14.96             59.84
# AFG                               NaN               NaN
# AGO                               NaN               NaN
# AIA                               NaN               NaN
# ALB                             26.67            120.15
#
#           excess_mortality_cumulative_per_million
# iso_code
# ABW                                    617.566118
# AFG                                           NaN
# AGO                                           NaN
# AIA                                           NaN
# ALB                                   2023.158207
#
# [5 rows x 65 columns]

# %%
norm_covid_2020=covid_2020.copy()
# since cases number varies alot, apply z-score standardlization to total_cases column to normalize the case number
norm_covid_2020=norm_covid_2020.sort_values(by='total_cases')
norm_covid_2020['norm_total_cases'] = (norm_covid_2020['total_cases'] - norm_covid_2020['total_cases'].mean())\
                                    / (norm_covid_2020['total_cases'].std())    

display(norm_covid_2020)
# Out:
#          continent             location        date  total_cases  new_cases  \
# iso_code
# VUT        Oceania              Vanuatu  2020-12-31          1.0        1.0
# WSM        Oceania                Samoa  2020-12-31          2.0        1.0
# WLF        Oceania    Wallis and Futuna  2020-12-31          4.0        1.0
# MHL        Oceania     Marshall Islands  2020-12-31          4.0        3.0
# SHN         Africa         Saint Helena  2020-12-31          4.0        2.0
# ...            ...                  ...         ...          ...        ...
# OWID_NAM       NaN        North America  2020-12-31   23150275.0   286075.0
# OWID_EUR       NaN               Europe  2020-12-31   23859991.0   345394.0
# OWID_UMC       NaN  Upper middle income  2020-12-31   25097583.0   212105.0
# OWID_HIC       NaN          High income  2020-12-31   41112430.0   512679.0
# OWID_WRL       NaN                World  2020-12-31   83735279.0   775182.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# VUT                    0.143           NaN         NaN                  NaN
# WSM                    0.143           NaN         NaN                  NaN
# WLF                    0.143           NaN         NaN                  NaN
# MHL                    0.429           NaN         NaN                  NaN
# SHN                    0.286           NaN         NaN                  NaN
# ...                      ...           ...         ...                  ...
# OWID_NAM          245712.143      512711.0      5212.0             3668.429
# OWID_EUR          293718.143      545520.0      6443.0             5002.714
# OWID_UMC          182072.714      714172.0      5584.0             3686.714
# OWID_HIC          402064.429      832844.0      9423.0             6838.429
# OWID_WRL          650281.286     1880791.0     15629.0            11841.286
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# iso_code                           ...
# VUT                         3.180  ...        34.500                  25.209
# WSM                         9.993  ...        38.100                     NaN
# WLF                       360.555  ...           NaN                     NaN
# MHL                        67.094  ...           NaN                  82.502
# SHN                       656.276  ...           NaN                     NaN
# ...                           ...  ...           ...                     ...
# OWID_NAM                38804.897  ...           NaN                     NaN
# OWID_EUR                31857.370  ...           NaN                     NaN
# OWID_UMC                 9984.427  ...           NaN                     NaN
# OWID_HIC                33839.334  ...           NaN                     NaN
# OWID_WRL                10633.098  ...        34.635                  60.130
#
#           hospital_beds_per_thousand  life_expectancy  \
# iso_code
# VUT                              NaN            70.47
# WSM                              NaN            73.32
# WLF                              NaN            79.94
# MHL                            2.700            73.70
# SHN                              NaN            80.56
# ...                              ...              ...
# OWID_NAM                         NaN              NaN
# OWID_EUR                         NaN              NaN
# OWID_UMC                         NaN              NaN
# OWID_HIC                         NaN              NaN
# OWID_WRL                       2.705            72.58
#
#           human_development_index  excess_mortality_cumulative_absolute  \
# iso_code
# VUT                         0.609                                   NaN
# WSM                         0.715                                   NaN
# WLF                           NaN                                   NaN
# MHL                         0.704                                   NaN
# SHN                           NaN                                   NaN
# ...                           ...                                   ...
# OWID_NAM                      NaN                                   NaN
# OWID_EUR                      NaN                                   NaN
# OWID_UMC                      NaN                                   NaN
# OWID_HIC                      NaN                                   NaN
# OWID_WRL                    0.737                                   NaN
#
#           excess_mortality_cumulative  excess_mortality  \
# iso_code
# VUT                               NaN               NaN
# WSM                               NaN               NaN
# WLF                               NaN               NaN
# MHL                               NaN               NaN
# SHN                               NaN               NaN
# ...                               ...               ...
# OWID_NAM                          NaN               NaN
# OWID_EUR                          NaN               NaN
# OWID_UMC                          NaN               NaN
# OWID_HIC                          NaN               NaN
# OWID_WRL                          NaN               NaN
#
#           excess_mortality_cumulative_per_million  norm_total_cases
# iso_code
# VUT                                           NaN         -0.216846
# WSM                                           NaN         -0.216846
# WLF                                           NaN         -0.216846
# MHL                                           NaN         -0.216846
# SHN                                           NaN         -0.216846
# ...                                           ...               ...
# OWID_NAM                                      NaN          2.976719
# OWID_EUR                                      NaN          3.074624
# OWID_UMC                                      NaN          3.245349
# OWID_HIC                                      NaN          5.454587
# OWID_WRL                                      NaN         11.334382
#
# [223 rows x 66 columns]

# %%
#Observed the world data on last row, remove for outlier data point
norm_covid_2020=norm_covid_2020[:-1] 
display(norm_covid_2020)
plt.hist(norm_covid_2020['norm_total_cases'],bins=50)
plt.show()
# Out:
#          continent             location        date  total_cases  new_cases  \
# iso_code
# VUT        Oceania              Vanuatu  2020-12-31          1.0        1.0
# WSM        Oceania                Samoa  2020-12-31          2.0        1.0
# WLF        Oceania    Wallis and Futuna  2020-12-31          4.0        1.0
# MHL        Oceania     Marshall Islands  2020-12-31          4.0        3.0
# SHN         Africa         Saint Helena  2020-12-31          4.0        2.0
# ...            ...                  ...         ...          ...        ...
# OWID_ASI       NaN                 Asia  2020-12-31   20716183.0   146135.0
# OWID_NAM       NaN        North America  2020-12-31   23150275.0   286075.0
# OWID_EUR       NaN               Europe  2020-12-31   23859991.0   345394.0
# OWID_UMC       NaN  Upper middle income  2020-12-31   25097583.0   212105.0
# OWID_HIC       NaN          High income  2020-12-31   41112430.0   512679.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# VUT                    0.143           NaN         NaN                  NaN
# WSM                    0.143           NaN         NaN                  NaN
# WLF                    0.143           NaN         NaN                  NaN
# MHL                    0.429           NaN         NaN                  NaN
# SHN                    0.286           NaN         NaN                  NaN
# ...                      ...           ...         ...                  ...
# OWID_ASI          129001.000      337854.0      2524.0             1848.714
# OWID_NAM          245712.143      512711.0      5212.0             3668.429
# OWID_EUR          293718.143      545520.0      6443.0             5002.714
# OWID_UMC          182072.714      714172.0      5584.0             3686.714
# OWID_HIC          402064.429      832844.0      9423.0             6838.429
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# iso_code                           ...
# VUT                         3.180  ...          34.5                  25.209
# WSM                         9.993  ...          38.1                     NaN
# WLF                       360.555  ...           NaN                     NaN
# MHL                        67.094  ...           NaN                  82.502
# SHN                       656.276  ...           NaN                     NaN
# ...                           ...  ...           ...                     ...
# OWID_ASI                 4428.006  ...           NaN                     NaN
# OWID_NAM                38804.897  ...           NaN                     NaN
# OWID_EUR                31857.370  ...           NaN                     NaN
# OWID_UMC                 9984.427  ...           NaN                     NaN
# OWID_HIC                33839.334  ...           NaN                     NaN
#
#           hospital_beds_per_thousand  life_expectancy  \
# iso_code
# VUT                              NaN            70.47
# WSM                              NaN            73.32
# WLF                              NaN            79.94
# MHL                              2.7            73.70
# SHN                              NaN            80.56
# ...                              ...              ...
# OWID_ASI                         NaN              NaN
# OWID_NAM                         NaN              NaN
# OWID_EUR                         NaN              NaN
# OWID_UMC                         NaN              NaN
# OWID_HIC                         NaN              NaN
#
#           human_development_index  excess_mortality_cumulative_absolute  \
# iso_code
# VUT                         0.609                                   NaN
# WSM                         0.715                                   NaN
# WLF                           NaN                                   NaN
# MHL                         0.704                                   NaN
# SHN                           NaN                                   NaN
# ...                           ...                                   ...
# OWID_ASI                      NaN                                   NaN
# OWID_NAM                      NaN                                   NaN
# OWID_EUR                      NaN                                   NaN
# OWID_UMC                      NaN                                   NaN
# OWID_HIC                      NaN                                   NaN
#
#           excess_mortality_cumulative  excess_mortality  \
# iso_code
# VUT                               NaN               NaN
# WSM                               NaN               NaN
# WLF                               NaN               NaN
# MHL                               NaN               NaN
# SHN                               NaN               NaN
# ...                               ...               ...
# OWID_ASI                          NaN               NaN
# OWID_NAM                          NaN               NaN
# OWID_EUR                          NaN               NaN
# OWID_UMC                          NaN               NaN
# OWID_HIC                          NaN               NaN
#
#           excess_mortality_cumulative_per_million  norm_total_cases
# iso_code
# VUT                                           NaN         -0.216846
# WSM                                           NaN         -0.216846
# WLF                                           NaN         -0.216846
# MHL                                           NaN         -0.216846
# SHN                                           NaN         -0.216846
# ...                                           ...               ...
# OWID_ASI                                      NaN          2.640938
# OWID_NAM                                      NaN          2.976719
# OWID_EUR                                      NaN          3.074624
# OWID_UMC                                      NaN          3.245349
# OWID_HIC                                      NaN          5.454587
#
# [222 rows x 66 columns]

# %% [markdown]
# #### Highest % of COVID deaths in the world

# %%
covid = pd.read_csv(os.getcwd()+"/data files/owid-covid-data.csv")[["location", "date", "new_deaths"]]

covid["date"] = pd.to_datetime(covid["date"]).dt.year

top_10_covid = covid.groupby(["location", "date"], as_index = False).sum()

display(top_10_covid[:3])
# Out:
#       location  date  new_deaths
# 0  Afghanistan  2020      2189.0
# 1  Afghanistan  2021      5167.0
# 2  Afghanistan  2022         0.0

# %%
worldpop = pd.read_csv(os.getcwd()+"/data files/Worldpop.csv")

worldpop["PopTotal"] = worldpop["PopTotal"].astype(int)

display(worldpop[:3])
# Out:
#       Location  Time  PopTotal
# 0  Afghanistan  2020     38928
# 1  Afghanistan  2021     39943
# 2       Africa  2020   1340598

# %% [markdown]
# Join total population to covid deaths for comparison

# %%
top_10_covid = worldpop.merge(top_10_covid, left_on = ["Location", "Time"], right_on = ["location", "date"])

top_10_covid = top_10_covid.drop(columns = ["date", "location"])

# %%
display(top_10_covid[:3])
# Out:
#       Location  Time  PopTotal  new_deaths
# 0  Afghanistan  2020     38928      2189.0
# 1  Afghanistan  2021     39943      5167.0
# 2       Africa  2020   1340598     65468.0

# %%
# population total in 1000's 

top_10_covid["deaths percentage"] = (top_10_covid["new_deaths"]/(top_10_covid["PopTotal"]*1000))

top_10_covid = top_10_covid[top_10_covid["Location"] != "World"]

covid_countries = top_10_covid.sort_values(by = "deaths percentage", ascending = False)

# %%
covid_countries = covid_countries[:10]

display(covid_countries[:3])
# Out:
#      Location  Time  PopTotal  new_deaths  deaths percentage
# 59   Bulgaria  2021      6892     23379.0           0.003392
# 282      Peru  2021     33283    109583.0           0.003292
# 164   Hungary  2021      9627     29649.0           0.003080

# %%
covid_trend = top_10_covid[top_10_covid["Location"].isin(covid_countries["Location"].unique())]

display(covid_trend[:3])
# Out:
#                   Location  Time  PopTotal  new_deaths  deaths percentage
# 50  Bosnia and Herzegovina  2020      3280      4050.0           0.001235
# 51  Bosnia and Herzegovina  2021      3267      9392.0           0.002875
# 58                Bulgaria  2020      6948      7576.0           0.001090

# %%
sns.lineplot(x="Time", y="deaths percentage",
             hue="Location",data=covid_trend, palette="Set2", lw =3).set(title = "Countries with highest Covid-19 % of Deaths")

sns.set(rc={'figure.figsize':(15,6)})

sns.set_style("white")

# %%
# countries with most covid deaths 
continent = pd.read_csv(os.getcwd()+"/data files/countryContinent.csv")

continent = continent[["country", "continent"]]

covid_deaths = covid_trend.merge(continent, left_on = "Location", right_on = "country")

covid_deaths = covid_deaths.drop(columns = ["country"])

display(covid_deaths["continent"].unique())
# Out:
# array(['Europe', 'Asia', 'Americas'], dtype=object)

# %% [markdown]
# ## Create a scoring system for the countries

# %% [markdown]
# We created a scoring system for all countries to see if there is a possible corellation of malnutrition with COVID-19 survival rate.
#
# The malnutrition score is the sum of all 3 types of malnutrition measurements for a final total 'score'.
#
# The COVID-19 score is a function of total number of deaths divided by the length of time since the country first reported a death. Since the COVID-19 data covers a very short time span, countries can have vastly different total deaths depending on the length of time it has been present in each country. Since a glimpse at the data we retrieved seems to show daily reports, we have made an average daily deathrate by dividing the total deaths (as of 31 December 2020) by the number of days deaths have been in the reports by country.

# %%
# calculate a malnutrition score for each country
mal_score = combined_df.copy()
mal_score['mscore'] = mal_score['Overweight_percent']+mal_score['Waste_total_percent']+mal_score['Stunt_total_percent']
mal_score.drop(labels=['Overweight_percent', 'Waste_total_percent', 'Stunt_total_percent', 'Mean', 'Year'], axis=1, inplace=True)
mal_score = mal_score.groupby(by=['Country Name']).mean()
print('Malnutrition score range is from ', round(max(mal_score['mscore']),3), 'to', round(min(mal_score['mscore']),3))
# Out:
# Malnutrition score range is from  107.675 to 6.1

# %% [markdown]
# Since the malnutrition data is a percentage and the covid data is not a percentage, we need to normalize the data to the same scale as each other. We have chosen a scale of zero to ten because the graphs in this section respond best to this scale.

# %%
# normalize the score values
scaler = MinMaxScaler(feature_range=(0,10))
ms = scaler.fit_transform(mal_score)
scaled_mal_score = pd.DataFrame(ms, index=mal_score.index, columns=mal_score.columns)
print('Malnutrition score has been normalized to a range from ', round(max(scaled_mal_score['mscore']),3), 'to', round(min(scaled_mal_score['mscore']),3))
display(scaled_mal_score.head(2))
# Out:
# Malnutrition score has been normalized to a range from  10.0 to 0.0
#                 mscore
# Country Name
# Afghanistan   7.793913
# Albania       6.677332

# %%
# filter the covid dataframe to only have the columns necessary
covid_score = covid_data.copy()
covid_score = covid_score[['location', 'date', 'total_deaths']]

# count how many times the country name occurs so we know how many dates they have had COVID-19
counts = pd.DataFrame(covid_score['location'].value_counts(dropna=False))
counts.rename(columns={'location':'days_reported'}, inplace=True)
print('Count of the number of days each country has reported COVID-19 data.')
display(counts.head())
# Out:
# Count of the number of days each country has reported COVID-19 data.
#            days_reported
# Mexico               366
# Argentina            366
# Peru                 366
# Thailand             363
# Taiwan               351

# %%
# find last known total number of deaths for each country
deaths = covid_score.groupby(by='location').max()
print('Total number of deaths by country')
display(deaths.head(2))
# Out:
# Total number of deaths by country
#                    date  total_deaths
# location
# Afghanistan  2020-12-31        2189.0
# Africa       2020-12-31       65468.0

# %%
# calculate the covid score for each country
cscore =  deaths.merge(counts, left_on='location', right_index=True)
cscore['cscore'] = cscore['total_deaths'] / cscore['days_reported']
cscore.drop(labels=['date', 'total_deaths', 'days_reported'], axis=1, inplace=True)

# there were 7 countries with no covid score
cscore.fillna(0, inplace=True)

# filter to only have countries, not regions or 'World'
cscore = cscore[cscore.index.isin(countries)]
print('Covid score range is from ', round(max(cscore['cscore']),3), 'to', round(min(cscore['cscore']),3))
display(cscore.head(2))
# Out:
# Covid score range is from  1019.577 to 0.0
#                cscore
# location
# Afghanistan  7.016026
# Albania      3.797428

# %%
# normalize the score values
scaler2 = MinMaxScaler(feature_range=(0,10))
cs = scaler2.fit_transform(cscore)
scaled_covid_score = pd.DataFrame(cs, index=cscore.index, columns=cscore.columns)
print('Covid score has been normalized to a range is from ', round(max(scaled_covid_score['cscore']),3), 'to', round(min(scaled_covid_score['cscore']),3))
# Out:
# Covid score has been normalized to a range is from  10.0 to 0.0

# %%
scaled_covid_score.sort_values(by='cscore', ascending=False)
# Out:
#                                      cscore
# location
# United States                     50.000000
# Brazil                            30.859103
# India                             21.681480
# Mexico                            16.856747
# Peru                              12.470351
# ...                                     ...
# Laos                               0.000000
# Saint Kitts and Nevis              0.000000
# Bhutan                             0.000000
# Saint Vincent and the Grenadines   0.000000
# Samoa                              0.000000
#
# [179 rows x 1 columns]

# %%
# join the scores for comparison
merged_scores = scaled_mal_score.merge(scaled_covid_score, left_index=True, right_index=True)
display(merged_scores.head(2))
# Out:
#                mscore    cscore
# Afghanistan  7.793913  0.068813
# Albania      6.677332  0.037245

# %%
# now observe distribution
fig, axis2 = plt.subplots(1,2) 
fig.suptitle("Scores Distribution Boxplot", fontsize=20)

# Malnutrition score
axis2[0].boxplot(merged_scores['mscore'])
axis2[0].set_title("Malnutrition score distribution")

# COVID-19 score
axis2[1].boxplot(merged_scores['cscore'])
axis2[1].set_title("COVID-19 score distribution")
# Out:
# Text(0.5, 1.0, 'COVID-19 score distribution')

# %% [markdown]
# The distribution of the COVID-19 score is highly skewed to the right (large portion of the data is small with a long tail to the larger values) because this is still very new information with very little data and has not had time to normalize. We believe the data distribution will change over time.

# %%
# scatterplot of scores to look for correlation
x1 = merged_scores['mscore']
y1 = merged_scores['cscore']

plt.scatter(x1, y1, color='royalblue', alpha=0.3)
plt.title('COVID-19 score vs. Malnutrition score', fontsize=20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("Malnutrition score")
plt.ylabel("COVID-19 score")

m1, b1 = np.polyfit(x1, y1, 1)

plt.plot(x1, m1*x1 +b1, 'royalblue')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Creating an interaction term is a measurable way to see the effect of malnutrition on COVID-19 deathrate based on the scores we just created and assigned to each country. This interaction term is the malnutrition score times the COVID-19 score. By multiplying the two scores, we zero out countries for which we have '0' for either score data.

# %%
# now create an interaction term for easy comparison
merged_scores['interaction_term'] = merged_scores['mscore'] * merged_scores['cscore']
merged_scores = merged_scores.sort_values(by=['interaction_term'], ascending=False)
display('Top 5 countries where COVID-19 has a large affect compared to malnutrition', merged_scores[:5])#, 'Bottom 5', merged_scores[-5:])
# Out:
# 'Top 5 countries where COVID-19 has a large affect compared to malnutrition'
#                  mscore     cscore  interaction_term
# India          7.830011   4.336296         33.953245
# Brazil         2.044466   6.171821         12.618079
# Mexico         2.416230   3.371349          8.145956
# Peru           3.006399   2.494070          7.498171
# United States  0.570112  10.000000          5.701117

# %%
plt.plot(merged_scores['interaction_term'],merged_scores.index)
plt.axvline(x=0.5, color='red', linestyle='--')
plt.title('Distribution of Interaction Term', fontsize=20)
plt.ylabel('Countries')
plt.show()

# %% [markdown]
# Now, let's isolate the outliers and look at those countries. Based on the distribution charted above, we'll call outliers any country with an interaction term of 0.5 or greater.

# %%
# isolate the outliers
outliers = merged_scores[merged_scores.interaction_term >= 0.5] #.tolist()
display(outliers)
# Out:
#                  mscore     cscore  interaction_term
# India          7.830011   4.336296         33.953245
# Brazil         2.044466   6.171821         12.618079
# Mexico         2.416230   3.371349          8.145956
# Peru           3.006399   2.494070          7.498171
# United States  0.570112  10.000000          5.701117
# Indonesia      6.814106   0.711899          4.850958
# Ukraine        6.694561   0.622065          4.164454
# South Africa   4.297317   0.848704          3.647151
# Colombia       1.967019   1.408082          2.769725
# Pakistan       8.133563   0.320920          2.610223
# Bangladesh     7.170400   0.243877          1.748695
# Argentina      1.496431   1.158870          1.734170
# Iraq           4.166872   0.402788          1.678365
# Ecuador        3.613094   0.449821          1.625247
# Turkey         2.325047   0.691894          1.608686
# Egypt          5.809922   0.232437          1.350442
# Romania        2.608910   0.498847          1.301447
# Philippines    4.761014   0.269036          1.280883
# Guatemala      7.887439   0.147981          1.167189
# Morocco        4.323570   0.220248          0.952256
# Saudi Arabia   2.776274   0.200115          0.555574
# Afghanistan    7.793913   0.068813          0.536323
# Myanmar        5.461974   0.093947          0.513134

# %% [markdown]
# The bubble plot below shows countries who have a large interaction between the malnutrition scores and COVID-19 scores we created. The bubble size is representative of the value of the interaction term whereas the bubble placement shows which score has the most weight in the calculation.

# %%
# bubble plot
plt.figure(figsize=(15, 15))
plt.scatter(outliers['mscore'], outliers['cscore'],
            color = 'purple', #ccan also be c=outliers['interaction_term']
            alpha=0.5,
            s = outliers['interaction_term'] * 2000)
plt.title('Coutries with highest correlation COVID-19 score vs. Malnutrition score', fontsize=20)
plt.xlabel('Malnutrition score', size=14)
plt.ylabel('COVID-19 score', size=14)

for i, txt in enumerate(list(outliers.index)):
    plt.annotate(txt, (outliers['mscore'][i], outliers['cscore'][i]), ha='center')

# %% [markdown]
# ## About the authors:

# %% [markdown]
# The authors met as students in Georgia Institue of Technology's Master of Science in Analytics program.  They were in a study group together for the Introduction for Computing for Data Analytics (CSE 6040) class in Fall 2021.

# %% [markdown]
# #### Yuxin Lui

# %% [markdown]
# https://www.linkedin.com/in/yuxin-liu-97108bb0/

# %% [markdown]
# #### Rutuja Patil

# %% [markdown]
# https://www.linkedin.com/in/rutuja-patil-b2804413b/

# %% [markdown]
# #### Kimberly Austin

# %% [markdown]
# https://www.linkedin.com/in/kimberly-austin-ga/
